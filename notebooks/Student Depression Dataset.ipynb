# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder ## coding the categorical variables
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
data = '../data/raw/Student Depression Dataset.csv'
pd = pd.read_csv(data)

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  object
#  11  Dietary Habits                         27901 non-null  object
#  12  Degree                                 27901 non-null  object
#  13  Have you ever had suicidal thoughts ?  27901 non-null  object
#  14  Work/Study Hours                       27901 non-null  float64
#  15  Financial Stress                       27898 non-null  float64
#  16  Family History of Mental Illness       27901 non-null  object
#  17  Depression                             27901 non-null  int64
# dtypes: float64(8), int64(2), object(8)
# memory usage: 3.8+ MB

# %%
pd.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# min        0.000000            0.000000          0.000000          0.000000
# 25%        6.290000            2.000000          0.000000          4.000000
# 50%        7.770000            3.000000          0.000000          8.000000
# 75%        8.920000            4.000000          0.000000         10.000000
# max       10.000000            5.000000          4.000000         12.000000
#
#        Financial Stress    Depression
# count      27898.000000  27901.000000
# mean           3.139867      0.585499
# std            1.437347      0.492645
# min            1.000000      0.000000
# 25%            2.000000      0.000000
# 50%            3.000000      1.000000
# 75%            4.000000      1.000000
# max            5.000000      1.000000

# %%
pd.head(10)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
# 5  33    Male  29.0           Pune    Student                2.0
# 6  52    Male  30.0          Thane    Student                3.0
# 7  56  Female  30.0        Chennai    Student                2.0
# 8  59    Male  28.0         Nagpur    Student                3.0
# 9  62    Male  31.0         Nashik    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
# 5            0.0  5.70                 3.0               0.0
# 6            0.0  9.54                 4.0               0.0
# 7            0.0  8.04                 4.0               0.0
# 8            0.0  9.79                 1.0               0.0
# 9            0.0  8.38                 3.0               0.0
#
#       Sleep Duration Dietary Habits    Degree  \
# 0          5-6 hours        Healthy   B.Pharm
# 1          5-6 hours       Moderate       BSc
# 2  Less than 5 hours        Healthy        BA
# 3          7-8 hours       Moderate       BCA
# 4          5-6 hours       Moderate    M.Tech
# 5  Less than 5 hours        Healthy       PhD
# 6          7-8 hours        Healthy       BSc
# 7  Less than 5 hours      Unhealthy  Class 12
# 8          7-8 hours       Moderate      B.Ed
# 9  Less than 5 hours       Moderate       LLB
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                   Yes               3.0               1.0
# 1                                    No               3.0               2.0
# 2                                    No               9.0               1.0
# 3                                   Yes               4.0               5.0
# 4                                   Yes               1.0               1.0
# 5                                    No               4.0               1.0
# 6                                    No               1.0               2.0
# 7                                    No               0.0               1.0
# 8                                   Yes              12.0               3.0
# 9                                   Yes               2.0               5.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0
# 5                               No           0
# 6                               No           0
# 7                              Yes           0
# 8                               No           1
# 9                               No           1

# %%
## Agrupacion de datos si esta o no deprimido
agrupados_depresion = pd.groupby('Depression')
print(agrupados_depresion.size())
# Out:
# Depression
# 0    11565
# 1    16336
# dtype: int64

# %%
##verificar si hay datos nulos
print(pd.isnull().sum())
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
## Rellenar los datos nulos con la media
pd.loc[:, 'Financial Stress'] = pd['Financial Stress'].fillna(pd['Financial Stress'].mean())
print(pd.isnull().sum())
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
##codificar las variables categoricas
print(pd['Dietary Habits'].value_counts())
# Out:
# Dietary Habits
# Unhealthy    10317
# Moderate      9921
# Healthy       7651
# Others          12
# Name: count, dtype: int64

# %%
## columnas que tienen datos numericos
numerical_columns = ['Age', 'Academic Pressure', 'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction', 'Work/Study Hours', 'Financial Stress']

# %%
# Define nominal and ordinal columns
nominal_columns = ['Gender', 'City', 'Profession', 'Degree']
ordinal_columns = {
    'Sleep Duration': ['Less than 5 hours', '5-6 hours',  '7-8 hours', 'More than 8 hours', 'Others'],  # Example levels
    'Have you ever had suicidal thoughts ?': ['No', 'Yes'],  # Example levels
    'Family History of Mental Illness': ['No', 'Yes'],  # Example levels
    'Dietary Habits': ['Unhealthy', 'Moderate', 'Healthy', 'Others']  # Example levels
}

# %%
# Encode nominal columns using LabelEncoder
label_encoders = {}
for column in nominal_columns:
    le = LabelEncoder()
    pd[column] = le.fit_transform(pd[column])
    label_encoders[column] = le

# %%
# Encode ordinal columns using OrdinalEncoder
ordinal_encoder = OrdinalEncoder(categories=[ordinal_columns[col] for col in ordinal_columns])
pd[list(ordinal_columns.keys())] = ordinal_encoder.fit_transform(pd[list(ordinal_columns.keys())])

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  int64
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  int64
#  4   Profession                             27901 non-null  int64
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  float64
#  11  Dietary Habits                         27901 non-null  float64
#  12  Degree                                 27901 non-null  int64
#  13  Have you ever had suicidal thoughts ?  27901 non-null  float64
#  14  Work/Study Hours                       27901 non-null  float64
#  15  Financial Stress                       27901 non-null  float64
#  16  Family History of Mental Illness       27901 non-null  float64
#  17  Depression                             27901 non-null  int64
# dtypes: float64(12), int64(6)
# memory usage: 3.8 MB

# %%
# limitar los datos atipicos
for column in numerical_columns:
    q1 = pd[column].quantile(0.25)
    q3 = pd[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    pd[column] = pd[column].clip(lower_bound, upper_bound)

# %%
# Separar datos para entrenamiento y prueba
x = pd.drop(['Depression', 'id'], axis=1)
y = pd['Depression']

# %%
# Train a Random Forest classifier
model = RandomForestClassifier(n_estimators=100, random_state=12)
model.fit(x, y)
# Out:
# RandomForestClassifier(random_state=12)

# %%
# Get feature importances
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
# Print the feature ranking
print("Feature ranking:")

for i in range(x.shape[1]):
    print(f"{i + 1}. feature {x.columns[indices[i]]} ({importances[indices[i]]})")
# Out:
# Feature ranking:
# 1. feature Have you ever had suicidal thoughts ? (0.23889148134746588)
# 2. feature Academic Pressure (0.15660371472249826)
# 3. feature Financial Stress (0.09064215335479187)
# 4. feature CGPA (0.08708780937546587)
# 5. feature Age (0.08343075313050873)
# 6. feature City (0.07193481979988618)
# 7. feature Work/Study Hours (0.06866401386562135)
# 8. feature Degree (0.0625900904393325)
# 9. feature Study Satisfaction (0.04184797120391262)
# 10. feature Dietary Habits (0.03482008249354271)
# 11. feature Sleep Duration (0.0326287408989336)
# 12. feature Gender (0.015450977116410997)
# 13. feature Family History of Mental Illness (0.015132599308699443)
# 14. feature Profession (0.0002747929429300404)
# 15. feature Job Satisfaction (0.0)
# 16. feature Work Pressure (0.0)

# %%
## normalizacion de los datos
scaler = StandardScaler()
pd[numerical_columns] = scaler.fit_transform(pd[numerical_columns])

pd.head()
# Out:
#    id  Gender       Age  City  Profession  Academic Pressure  Work Pressure  \
# 0   2       1  1.468036    51          11           1.345543            0.0
# 1   8       0 -0.371929     3          11          -0.826104            0.0
# 2  26       1  1.059155    44          11          -0.102222            0.0
# 3  30       0  0.445833    49          11          -0.102222            0.0
# 4  32       0 -0.167489    16          11           0.621660            0.0
#
#        CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0  0.894910           -0.693425               0.0             1.0
# 1 -1.197308            1.510636               0.0             1.0
# 2 -0.427208            1.510636               0.0             0.0
# 3 -1.408574           -0.693425               0.0             2.0
# 4  0.322447            0.041262               0.0             1.0
#
#    Dietary Habits  Degree  Have you ever had suicidal thoughts ?  \
# 0             2.0       3                                    1.0
# 1             1.0      10                                    0.0
# 2             2.0       5                                    0.0
# 3             1.0       7                                    1.0
# 4             1.0      17                                    1.0
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0         -1.121213         -1.488868                               0.0
# 1         -1.121213         -0.793092                               1.0
# 2          0.497095         -1.488868                               1.0
# 3         -0.851495          1.294237                               1.0
# 4         -1.660650         -1.488868                               0.0
#
#    Depression
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
